# %%
from statsbombpy import sb

# %% [markdown]
# ### All Competitions

# %%
df_competitions = sb.competitions()
df_competitions.head()
# Out:
# /Users/frankandrade/AnalyticsProjects/world-cup/world-cup-venv/lib/python3.10/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#    competition_id  season_id country_name  competition_name  \
# 0              16          4       Europe  Champions League
# 1              16          1       Europe  Champions League
# 2              16          2       Europe  Champions League
# 3              16         27       Europe  Champions League
# 4              16         26       Europe  Champions League
#
#   competition_gender  competition_youth  competition_international  \
# 0               male              False                      False
# 1               male              False                      False
# 2               male              False                      False
# 3               male              False                      False
# 4               male              False                      False
#
#   season_name               match_updated        match_updated_360  \
# 0   2018/2019  2022-08-14T16:57:15.866765  2021-06-13T16:17:31.694
# 1   2017/2018  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 2   2016/2017  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 3   2015/2016  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 4   2014/2015  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
#
#   match_available_360             match_available
# 0                None  2022-08-14T16:57:15.866765
# 1                None  2021-01-23T21:55:30.425330
# 2                None            2020-07-29T05:00
# 3                None            2020-07-29T05:00
# 4                None            2020-07-29T05:00

# %% [markdown]
# ### FIFA World Cup 2018

# %%
df_2018 = sb.matches(competition_id=43, season_id=3)
df_2018
# Out:
# /Users/frankandrade/AnalyticsProjects/world-cup/world-cup-venv/lib/python3.10/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     match_id  match_date      kick_off                     competition season  \
# 0       7548  2018-06-22  14:00:00.000  International - FIFA World Cup   2018
# 1       7578  2018-06-15  14:00:00.000  International - FIFA World Cup   2018
# 2       7553  2018-06-23  17:00:00.000  International - FIFA World Cup   2018
# 3       7544  2018-06-20  17:00:00.000  International - FIFA World Cup   2018
# 4       7536  2018-06-18  17:00:00.000  International - FIFA World Cup   2018
# ..       ...         ...           ...                             ...    ...
# 59      7540  2018-06-19  20:00:00.000  International - FIFA World Cup   2018
# 60      8652  2018-07-07  20:00:00.000  International - FIFA World Cup   2018
# 61      7563  2018-06-26  16:00:00.000  International - FIFA World Cup   2018
# 62      7556  2018-06-24  17:00:00.000  International - FIFA World Cup   2018
# 63      7559  2018-06-25  16:00:00.000  International - FIFA World Cup   2018
#
#        home_team     away_team  home_score  away_score match_status  ...  \
# 0         Brazil    Costa Rica           2           0    available  ...
# 1          Egypt       Uruguay           0           1    available  ...
# 2    South Korea        Mexico           1           2    available  ...
# 3        Uruguay  Saudi Arabia           1           0    available  ...
# 4        Belgium        Panama           3           0    available  ...
# ..           ...           ...         ...         ...          ...  ...
# 59        Russia         Egypt           3           1    available  ...
# 60        Russia       Croatia           2           2    available  ...
# 61       Denmark        France           0           0    available  ...
# 62         Japan       Senegal           2           2    available  ...
# 63  Saudi Arabia         Egypt           2           1    available  ...
#
#            last_updated_360 match_week competition_stage  \
# 0   2021-06-13T16:17:31.694          2       Group Stage
# 1   2021-06-13T16:17:31.694          1       Group Stage
# 2   2021-06-13T16:17:31.694          2       Group Stage
# 3   2021-06-13T16:17:31.694          2       Group Stage
# 4   2021-06-13T16:17:31.694          1       Group Stage
# ..                      ...        ...               ...
# 59  2021-06-13T16:17:31.694          2       Group Stage
# 60  2021-06-13T16:17:31.694          5    Quarter-finals
# 61  2021-06-13T16:17:31.694          3       Group Stage
# 62  2021-06-13T16:17:31.694          2       Group Stage
# 63  2021-06-13T16:17:31.694          3       Group Stage
#
#                          stadium                        referee  \
# 0       Saint-Petersburg Stadium                  Björn Kuipers
# 1           \tEkaterinburg Arena                  Björn Kuipers
# 2                 \tRostov Arena                  Milorad Mažić
# 3                 \tRostov Arena                 Clément Turpin
# 4   \tOlimpiyskiy Stadion Fisht                   Janny Sikazwe
# ..                           ...                            ...
# 59      Saint-Petersburg Stadium                Enrique Cáceres
# 60  \tOlimpiyskiy Stadion Fisht                    Sandro Ricci
# 61              Stadion Luzhniki                   Sandro Ricci
# 62          \tEkaterinburg Arena                Gianluca Rocchi
# 63               Volgograd Arena  Wilmar Alexander Roldán Pérez
#
#                      home_managers                    away_managers  \
# 0           Adenor Leonardo Bacchi  Óscar Antonio Ramírez Hernández
# 1                Héctor Raúl Cúper   Óscar Washington Tabárez Silva
# 2                    Tae-Yong Shin      Juan Carlos Osorio Arbeláez
# 3   Óscar Washington Tabárez Silva       Juan Antonio Pizzi Torroja
# 4        Roberto Martínez Montoliú     Hernán Darío Gómez Jaramillo
# ..                             ...                              ...
# 59            Stanislav Cherchesov                Héctor Raúl Cúper
# 60            Stanislav Cherchesov                     Zlatko Dalić
# 61            Åge Fridtjof Hareide                 Didier Deschamps
# 62                   Akira Nishino                      Aliou Cissé
# 63      Juan Antonio Pizzi Torroja                Héctor Raúl Cúper
#
#    data_version shot_fidelity_version xy_fidelity_version
# 0         1.0.2                  None                None
# 1         1.0.2                  None                None
# 2         1.0.2                  None                None
# 3         1.0.2                  None                None
# 4         1.0.2                  None                None
# ..          ...                   ...                 ...
# 59        1.0.2                  None                None
# 60        1.0.2                  None                None
# 61        1.0.2                  None                None
# 62        1.0.2                  None                None
# 63        1.0.2                  None                None
#
# [64 rows x 22 columns]

# %%
# Final France vs Croatia (8658)
id_final_2018 = 8658
df_2018[df_2018['match_id']==id_final_2018]
# Out:
#     match_id  match_date      kick_off                     competition season  \
# 32      8658  2018-07-15  17:00:00.000  International - FIFA World Cup   2018
#
#    home_team away_team  home_score  away_score match_status  ...  \
# 32    France   Croatia           4           2    available  ...
#
#            last_updated_360 match_week competition_stage           stadium  \
# 32  2021-06-13T16:17:31.694          7             Final  Stadion Luzhniki
#
#                  referee     home_managers away_managers data_version  \
# 32  Néstor Fabián Pitana  Didier Deschamps  Zlatko Dalić        1.0.2
#
#    shot_fidelity_version xy_fidelity_version
# 32                  None                None
#
# [1 rows x 22 columns]

# %% [markdown]
# ### Data About the Final France vs Croatia

# %%
df_lineups = sb.lineups(match_id=id_final_2018)
df_lineups.keys()
# Out:
# /Users/frankandrade/AnalyticsProjects/world-cup/world-cup-venv/lib/python3.10/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# dict_keys(['France', 'Croatia'])

# %%
df_lineups['Croatia']
df_lineups['France']
# Out:
#     player_id                                  player_name  player_nickname  \
# 0        2948                                  Nabil Fekir             None
# 1        3009                         Kylian Mbappé Lottin    Kylian Mbappé
# 2        3099                                  Hugo Lloris             None
# 3        3604                               Olivier Giroud             None
# 4        3961                                N''Golo Kanté     N'Golo Kanté
# 5        4375                               Blaise Matuidi             None
# 6        5476                              Benjamin Pavard             None
# 7        5480                             Corentin Tolisso             None
# 8        5484                           Lucas Hernández Pi  Lucas Hernandez
# 9        5485                               Raphaël Varane             None
# 10       5487                            Antoine Griezmann             None
# 11       5492                           Samuel Yves Umtiti    Samuel Umtiti
# 12       5737  Steven N''Kemboanza Mike Christopher Nzonzi    Steven Nzonzi
# 13      20004                                   Paul Pogba             None
#
#     jersey_number country                                              cards  \
# 0              18  France                                                 []
# 1              10  France                                                 []
# 2               1  France                                                 []
# 3               9  France                                                 []
# 4              13  France  [{'time': '26:52', 'card_type': 'Yellow Card',...
# 5              14  France                                                 []
# 6               2  France                                                 []
# 7              12  France                                                 []
# 8              21  France                                                 []
# 9               4  France                                                 []
# 10              7  France                                                 []
# 11              5  France                                                 []
# 12             15  France                                                 []
# 13              6  France                                                 []
#
#                                             positions
# 0   [{'position_id': 24, 'position': 'Left Center ...
# 1   [{'position_id': 12, 'position': 'Right Midfie...
# 2   [{'position_id': 1, 'position': 'Goalkeeper', ...
# 3   [{'position_id': 24, 'position': 'Left Center ...
# 4   [{'position_id': 11, 'position': 'Left Defensi...
# 5   [{'position_id': 16, 'position': 'Left Midfiel...
# 6   [{'position_id': 2, 'position': 'Right Back', ...
# 7   [{'position_id': 16, 'position': 'Left Midfiel...
# 8   [{'position_id': 6, 'position': 'Left Back', '...
# 9   [{'position_id': 3, 'position': 'Right Center ...
# 10  [{'position_id': 22, 'position': 'Right Center...
# 11  [{'position_id': 5, 'position': 'Left Center B...
# 12  [{'position_id': 11, 'position': 'Left Defensi...
# 13  [{'position_id': 9, 'position': 'Right Defensi...

# %%
df_events = sb.events(match_id=id_final_2018)
df_events.columns
# Out:
# /Users/frankandrade/AnalyticsProjects/world-cup/world-cup-venv/lib/python3.10/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Index(['ball_receipt_outcome', 'ball_recovery_recovery_failure',
#        'block_deflection', 'carry_end_location', 'clearance_aerial_won',
#        'counterpress', 'dribble_outcome', 'dribble_overrun', 'duel_outcome',
#        'duel_type', 'duration', 'foul_committed_advantage',
#        'foul_committed_card', 'foul_committed_penalty', 'foul_committed_type',
#        'foul_won_advantage', 'foul_won_defensive', 'goalkeeper_body_part',
#        'goalkeeper_end_location', 'goalkeeper_outcome', 'goalkeeper_position',
#        'goalkeeper_technique', 'goalkeeper_type', 'id', 'index',
#        'injury_stoppage_in_chain', 'interception_outcome', 'location',
#        'match_id', 'minute', 'pass_aerial_won', 'pass_angle',
#        'pass_assisted_shot_id', 'pass_backheel', 'pass_body_part',
#        'pass_cross', 'pass_cut_back', 'pass_deflected', 'pass_end_location',
#        'pass_goal_assist', 'pass_height', 'pass_length', 'pass_outcome',
#        'pass_recipient', 'pass_shot_assist', 'pass_switch', 'pass_type',
#        'period', 'play_pattern', 'player', 'player_id', 'position',
#        'possession', 'possession_team', 'possession_team_id', 'related_events',
#        'second', 'shot_aerial_won', 'shot_body_part', 'shot_deflected',
#        'shot_end_location', 'shot_first_time', 'shot_freeze_frame',
#        'shot_key_pass_id', 'shot_outcome', 'shot_statsbomb_xg',
#        'shot_technique', 'shot_type', 'substitution_outcome',
#        'substitution_replacement', 'tactics', 'team', 'timestamp', 'type',
#        'under_pressure'],
#       dtype='object')

# %%
df_events = df_events[['timestamp','team', 'type', 'minute', 'location', 'pass_end_location', 'player']]
# first seconds France vs Croatia
df_events.head(10)
# Out:
#       timestamp     team         type  minute      location pass_end_location  \
# 0  00:00:00.000   France  Starting XI       0           NaN               NaN
# 1  00:00:00.000  Croatia  Starting XI       0           NaN               NaN
# 2  00:00:00.000   France   Half Start       0           NaN               NaN
# 3  00:00:00.000  Croatia   Half Start       0           NaN               NaN
# 4  00:00:00.000  Croatia   Half Start      45           NaN               NaN
# 5  00:00:00.000   France   Half Start      45           NaN               NaN
# 6  00:00:00.400  Croatia         Pass       0  [61.0, 41.0]      [50.0, 42.0]
# 7  00:00:02.347  Croatia         Pass       0  [49.0, 41.0]      [44.0, 51.0]
# 8  00:00:03.947  Croatia         Pass       0  [43.0, 56.0]      [42.0, 79.0]
# 9  00:00:06.240  Croatia         Pass       0  [38.0, 78.0]      [10.0, 49.0]
#
#              player
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6   Mario Mandžukić
# 7  Marcelo Brozović
# 8       Luka Modrić
# 9     Šime Vrsaljko

# %%
# last 2 minutes France vs Croatia
df_events.sort_values(['minute', 'timestamp']).tail(50)
# Out:
#          timestamp     team            type  minute       location  \
# 839   00:48:00.907  Croatia            Pass      93   [44.0, 21.0]
# 1590  00:48:02.320  Croatia   Ball Receipt*      93   [56.0, 13.0]
# 2205  00:48:02.320  Croatia           Carry      93   [56.0, 13.0]
# 840   00:48:04.947  Croatia            Pass      93   [69.0, 11.0]
# 1591  00:48:06.200  Croatia   Ball Receipt*      93    [86.0, 2.0]
# 2206  00:48:06.200  Croatia           Carry      93    [86.0, 2.0]
# 841   00:48:08.147  Croatia            Pass      93    [95.0, 5.0]
# 1592  00:48:09.360  Croatia   Ball Receipt*      93   [105.0, 5.0]
# 2207  00:48:09.360   France           Carry      93   [17.0, 77.0]
# 2522  00:48:09.360   France            Duel      93   [17.0, 77.0]
# 2740  00:48:09.360  Croatia    Dispossessed      93   [104.0, 4.0]
# 842   00:48:10.987   France            Pass      93   [15.0, 79.0]
# 2208  00:48:15.640  Croatia           Carry      93    [58.0, 2.0]
# 2711  00:48:15.640  Croatia   Ball Recovery      93    [58.0, 2.0]
# 843   00:48:16.827  Croatia            Pass      93    [60.0, 2.0]
# 1593  00:48:18.280  Croatia   Ball Receipt*      93    [71.0, 8.0]
# 2209  00:48:18.280  Croatia           Carry      93    [71.0, 8.0]
# 844   00:48:20.587  Croatia            Pass      93   [75.0, 17.0]
# 1594  00:48:21.720  Croatia   Ball Receipt*      93   [88.0, 16.0]
# 2210  00:48:21.720  Croatia           Carry      93   [88.0, 16.0]
# 2467  00:48:22.082   France        Pressure      93   [32.0, 66.0]
# 2768  00:48:24.440   France  Foul Committed      93   [30.0, 63.0]
# 2795  00:48:24.440  Croatia        Foul Won      93   [91.0, 18.0]
# 2828  00:48:36.760  Croatia       Camera On      93            NaN
# 2555  00:48:37.760  Croatia      Miscontrol      93  [111.0, 21.0]
# 2468  00:48:38.040  Croatia        Pressure      93  [114.0, 21.0]
# 2962  00:48:40.067   France          Shield      93    [2.0, 61.0]
# 2829  00:49:14.507   France       Camera On      94            NaN
# 845   00:49:16.627   France            Pass      94   [70.0, 58.0]
# 1595  00:49:19.480   France   Ball Receipt*      94   [85.0, 44.0]
# 2211  00:49:19.480  Croatia           Carry      94   [24.0, 15.0]
# 2712  00:49:19.480  Croatia   Ball Recovery      94   [24.0, 15.0]
# 846   00:49:24.147  Croatia            Pass      94   [42.0, 17.0]
# 1596  00:49:26.547  Croatia   Ball Receipt*      94   [92.0, 31.0]
# 2212  00:49:26.547   France           Carry      94   [32.0, 61.0]
# 2713  00:49:26.547   France   Ball Recovery      94   [32.0, 61.0]
# 847   00:49:27.307   France            Pass      94   [31.0, 61.0]
# 848   00:49:32.120  Croatia            Pass      94    [50.0, 1.0]
# 1597  00:49:33.079  Croatia   Ball Receipt*      94    [58.0, 9.0]
# 2213  00:49:33.079  Croatia           Carry      94    [58.0, 9.0]
# 849   00:49:37.267  Croatia            Pass      94   [58.0, 14.0]
# 1598  00:49:38.707  Croatia   Ball Receipt*      94    [94.0, 2.0]
# 2214  00:49:38.707  Croatia           Carry      94    [94.0, 2.0]
# 2469  00:49:42.440   France        Pressure      94   [24.0, 77.0]
# 850   00:49:42.827  Croatia            Pass      94   [102.0, 4.0]
# 2215  00:49:45.427   France           Carry      94    [5.0, 33.0]
# 2960  00:49:45.427   France     Goal Keeper      94    [5.0, 33.0]
# 851   00:50:01.987   France            Pass      95   [18.0, 31.0]
# 2967  00:50:03.760   France        Half End      95            NaN
# 2968  00:50:03.760  Croatia        Half End      95            NaN
#
#      pass_end_location                player
# 839       [56.0, 13.0]          Dejan Lovren
# 1590               NaN      Marcelo Brozović
# 2205               NaN      Marcelo Brozović
# 840        [86.0, 2.0]      Marcelo Brozović
# 1591               NaN       Andrej Kramarić
# 2206               NaN       Andrej Kramarić
# 841       [105.0, 5.0]       Andrej Kramarić
# 1592               NaN          Ivan Perišić
# 2207               NaN       Benjamin Pavard
# 2522               NaN       Benjamin Pavard
# 2740               NaN          Ivan Perišić
# 842       [63.0, 79.0]       Benjamin Pavard
# 2208               NaN          Domagoj Vida
# 2711               NaN          Domagoj Vida
# 843        [71.0, 8.0]          Domagoj Vida
# 1593               NaN          Ivan Rakitić
# 2209               NaN          Ivan Rakitić
# 844       [88.0, 16.0]          Ivan Rakitić
# 1594               NaN      Marcelo Brozović
# 2210               NaN      Marcelo Brozović
# 2467               NaN           Nabil Fekir
# 2768               NaN           Nabil Fekir
# 2795               NaN      Marcelo Brozović
# 2828               NaN                   NaN
# 2555               NaN          Ivan Perišić
# 2468               NaN          Ivan Perišić
# 2962               NaN            Paul Pogba
# 2829               NaN                   NaN
# 845       [97.0, 66.0]           Nabil Fekir
# 1595               NaN  Kylian Mbappé Lottin
# 2211               NaN          Domagoj Vida
# 2712               NaN          Domagoj Vida
# 846       [89.0, 20.0]          Domagoj Vida
# 1596               NaN           Marko Pjaca
# 2212               NaN        Raphaël Varane
# 2713               NaN        Raphaël Varane
# 847       [68.0, 80.0]        Raphaël Varane
# 848        [58.0, 9.0]      Marcelo Brozović
# 1597               NaN          Ivan Rakitić
# 2213               NaN          Ivan Rakitić
# 849        [94.0, 2.0]          Ivan Rakitić
# 1598               NaN          Ivan Perišić
# 2214               NaN          Ivan Perišić
# 2469               NaN           Nabil Fekir
# 850      [116.0, 48.0]          Ivan Perišić
# 2215               NaN           Hugo Lloris
# 2960               NaN           Hugo Lloris
# 851       [52.0, 25.0]           Hugo Lloris
# 2967               NaN                   NaN
# 2968               NaN                   NaN

# %% [markdown]
# ### Free matches availables Statsbomb

# %%
import warnings
warnings.filterwarnings("ignore")

messages = []
for index, row in df.iterrows():
    try:
        competition = row['competition_id']
        season = row['season_id']
        country_name = row['country_name']
        competition_name = row['competition_name']
        season_name = row['season_name']
        number_matches = len(sb.matches(competition_id=competition, season_id=season))
        message = f'{country_name} {competition_name} {season_name} has {number_matches} available'
        messages.append(message)
    except:
        pass

# %%
for message in messages:
    print(message)
# Out:
# Europe Champions League 2018/2019 has 1 available
# Europe Champions League 2017/2018 has 1 available
# Europe Champions League 2016/2017 has 1 available
# Europe Champions League 2015/2016 has 1 available
# Europe Champions League 2014/2015 has 1 available
# Europe Champions League 2013/2014 has 1 available
# Europe Champions League 2012/2013 has 1 available
# Europe Champions League 2011/2012 has 1 available
# Europe Champions League 2010/2011 has 1 available
# Europe Champions League 2009/2010 has 1 available
# Europe Champions League 2008/2009 has 1 available
# Europe Champions League 2006/2007 has 1 available
# Europe Champions League 2004/2005 has 1 available
# Europe Champions League 2003/2004 has 1 available
# England FA Women's Super League 2020/2021 has 131 available
# England FA Women's Super League 2019/2020 has 87 available
# England FA Women's Super League 2018/2019 has 108 available
# International FIFA World Cup 2018 has 64 available
# India Indian Super league 2021/2022 has 115 available
# Spain La Liga 2020/2021 has 35 available
# Spain La Liga 2019/2020 has 33 available
# Spain La Liga 2018/2019 has 34 available
# Spain La Liga 2017/2018 has 36 available
# Spain La Liga 2016/2017 has 34 available
# Spain La Liga 2015/2016 has 33 available
# Spain La Liga 2014/2015 has 38 available
# Spain La Liga 2013/2014 has 31 available
# Spain La Liga 2012/2013 has 32 available
# Spain La Liga 2011/2012 has 37 available
# Spain La Liga 2010/2011 has 33 available
# Spain La Liga 2009/2010 has 35 available
# Spain La Liga 2008/2009 has 31 available
# Spain La Liga 2007/2008 has 28 available
# Spain La Liga 2006/2007 has 26 available
# Spain La Liga 2005/2006 has 17 available
# Spain La Liga 2004/2005 has 7 available
# United States of America NWSL 2018 has 36 available
# England Premier League 2003/2004 has 33 available
# Europe UEFA Euro 2020 has 51 available
# Europe UEFA Women's Euro 2022 has 31 available
# International Women's World Cup 2019 has 52 available
